# %%
# Dependencies and dataload
# Link to associated webkit
# http://scikit-learn.org/stable/modules/feature_selection.html#l1-feature-selection
# Module 1.13.4.3

import pandas as pd
from numpy import genfromtxt
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel

my_data = pd.read_csv('/Users/stevensun/Prometheus/0_data/prometheus.csv')
my_data.shape
# Out:
# (2377, 127)

# %%
#drop incomplete rows

my_data = my_data.dropna()
my_data.shape
# Out:
# (690, 127)

# %%
# vectorize data

X = my_data.ix[:,0:125]
y = my_data.ix[:,126]

# %%
# C controls sparcity: The smaller C, the fewer features selected
#
clf = ExtraTreesClassifier()
clf = clf.fit(X,y)
feature_weights = clf.feature_importances_
feature_weights
# Out:
# array([  1.60937847e-02,   1.81632211e-02,   1.82928326e-02,
#          2.09029089e-02,   2.12957153e-02,   3.27621431e-03,
#          0.00000000e+00,   0.00000000e+00,   9.51194885e-04,
#          2.64878082e-03,   1.17146127e-03,   0.00000000e+00,
#          2.22992386e-04,   3.01092509e-04,   1.12640496e-02,
#          8.95714662e-03,   1.21986650e-02,   0.00000000e+00,
#          8.99788709e-03,   1.77254729e-02,   1.80750726e-04,
#          2.35983272e-03,   5.15256281e-03,   4.42098540e-04,
#          1.58884384e-04,   5.45188160e-04,   0.00000000e+00,
#          0.00000000e+00,   6.62071999e-03,   1.10201327e-06,
#          5.67230365e-04,   6.24994866e-03,   6.21417235e-03,
#          8.70709420e-03,   8.83892216e-03,   7.81132560e-04,
#          7.70060689e-03,   3.17788703e-03,   8.17933330e-03,
#          2.51259026e-04,   8.63059031e-03,   4.31393729e-03,
#          3.00955075e-03,   9.39466352e-03,   1.35802491e-03,
#          3.10086650e-03,   2.86538718e-03,   1.41754532e-02,
#          1.04031364e-02,   8.57063716e-04,   4.80819229e-03,
#          1.71355985e-03,   1.77355694e-03,   2.86903407e-04,
#          1.92505475e-03,   1.23296930e-02,   7.11247258e-04,
#          3.86466806e-03,   1.42724619e-03,   1.39102735e-02,
#          1.94827153e-02,   1.86277060e-02,   2.48698764e-02,
#          2.04088656e-02,   1.89569193e-02,   2.38299141e-02,
#          1.22011164e-02,   8.79265789e-03,   2.77888066e-02,
#          2.29850195e-02,   2.47068215e-03,   8.12270022e-04,
#          1.88444270e-04,   1.27085735e-02,   1.39477871e-03,
#          1.51944206e-02,   1.45379232e-02,   2.84693377e-02,
#          6.15574741e-03,   1.12927628e-02,   6.64669098e-03,
#          1.71935313e-03,   2.49117337e-04,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   4.98761688e-04,
#          4.34717055e-03,   0.00000000e+00,   0.00000000e+00,
#          4.60880389e-03,   1.53494625e-02,   2.32104136e-03,
#          1.30415264e-02,   1.19463368e-02,   1.18734718e-03,
#          2.12362352e-02,   1.01678243e-02,   6.20001812e-03,
#          0.00000000e+00,   1.64825633e-03,   9.15184226e-04,
#          5.99595403e-04,   1.15074180e-03,   1.58016419e-03,
#          5.17427989e-03,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   2.07476139e-02,   1.94982195e-02,
#          1.98148700e-02,   1.99302345e-02,   2.18380457e-02,
#          1.71936060e-02,   2.43748250e-02,   2.13788353e-02,
#          1.64069537e-02,   1.22195897e-02,   6.24576097e-03,
#          1.55921008e-02,   1.36484096e-02,   1.37774500e-02,
#          1.26997180e-02,   1.34261039e-02])

# %%
# Create feature selected model
model = SelectFromModel(clf,prefit=True)
X_new = model.transform(X)
X_new.shape
# Out:
# (690, 54)

# %%
# Create list of features identified
features_selected = X.ix[:,model.get_support()]
feature_list = features_selected.columns

# %%
# Adjust to make human readable
# Create table of features and associated weights
coefficients = pd.DataFrame(feature_weights).transpose()
coefficients.columns = X.columns
coefficients[feature_list].transpose()
# Out:
#                                                 0
# SEX                                      0.016094
# BMI                                      0.018163
# AGE (normalized 30-80)                   0.018293
# ANAT_DEGREE_normalized VAR-VAL_-25_+25   0.020903
# RC_WHT                                   0.021296
# LTHPN_STD                                0.011264
# RTHPN_STD                                0.008957
# PTRT_NONE_YN                             0.012199
# PTRT_ARTHRO_YN                           0.008998
# PTRT_INTRA_INJECT_YN                     0.017725
# GM_CARDIO_YN                             0.008707
# GM_DEPRESS_YN                            0.008839
# GM_END_METABLIC_YN                       0.008179
# GM_GASTRO_DIS_YN                         0.008631
# GM_HEENT_YN                              0.009395
# GM_HYPTN_YN                              0.014175
# GM_HYPCHOL_YN                            0.010403
# GM_RESP_DIS_YN                           0.012330
# GM_OTHER_YN                              0.013910
# AP Alignment Angle                       0.019483
# Distal Femoral Angle                     0.018628
# Proximal Tibial Angle                    0.024870
# Femoral Component Flexion                0.020409
# Posterior Tibial Slope                   0.018957
# PROC_DUR_MIN (normalized 25 to 230 min)  0.023830
# DEVIMP_PSFB                              0.012201
# DEVIMP_PSRP                              0.008793
# DEVIMP_CRFB                              0.027789
# DEVIMP_CRRP                              0.022985
# SRG_APPROACH_MEDIAL_PARAPATELLAR         0.012709
# SRG_APPROACH_TRIVECTOR                   0.015194
# PAT_MANAGE_EVERTED                       0.014538
# PAT_MANAGE_SUBLUXED                      0.028469
# RESECTION_GAPBALANCE                     0.011293
# ANTI_CEMENT                              0.015349
# ST_NONE_YN                               0.013042
# ST_SYN_YN                                0.011946
# ST_DEEP_MCL_YN                           0.021236
# ST_POST_MED_CAP_YN                       0.010168
# preop PKIP confidence                    0.020748
# preop PKIP stability                     0.019498
# preop PKIP modify                        0.019815
# preop PKIP satisfaction                  0.019930
# preop PKIP total score                   0.021838
# preop KSS_EXT (norm 0 to 40)             0.017194
# preop KSS_FLEX (norm 70 to 150)          0.024375
# preop KS_PAIN_STAIRS                     0.021379
# postop KS_PAIN_WALK                      0.016407
# preop KS_PAT_EXP1                        0.012220
# preop KS_PAT_EXP3                        0.015592
# preop KS_PAT_SAT1                        0.013648
# preop KS_PAT_SAT2                        0.013777
# preop KS_PAT_SAT3                        0.012700
# preop KS_PAT_SAT4                        0.013426
