# %%
# Dependencies and dataload
# Link to associated webkit
# http://scikit-learn.org/stable/modules/feature_selection.html#l1-feature-selection

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt
import seaborn as sns

my_data = pd.read_csv('/Users/stevensun/Prometheus/0_data/prometheus.csv')
my_data.shape
# Out:
# (2377, 127)

# %%
#drop incomplete rows

my_data = my_data.dropna()
my_data.shape
# Out:
# (690, 127)

# %%
# vectorize data

X = my_data.ix[:,0:125]
y = my_data.ix[:,126]
X_headers = X.columns

# %%
##create linear regression model
lm = linear_model.LinearRegression()
lm.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Drow row values = 0
# Order from least to most
features = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficients'])
features = features[(features.T != 0).any()]
features.sort_values(by='Coefficients', ascending=1)
# Out:
#                                          Coefficients
# PRIDX4_OTHER                                -1.985370
# GM_FIBRO_POLY_YN                            -1.852518
# RC_ASIAN                                    -1.042558
# ST_BI_FEM_YN                                -0.992296
# DEVIMP_CRRP                                 -0.907706
# RC_AMIND                                    -0.811322
# RC_WHT                                      -0.752674
# GM_AUTOIMM_YN                               -0.747160
# preop KS_PAT_EXP1                           -0.673519
# DEVIMP_CRFB                                 -0.584668
# RC_BLCK                                     -0.557081
# ST_SYN_YN                                   -0.503684
# GM_PNERV_DIS_YN                             -0.452641
# GM_GENIT_DIS_YN                             -0.435982
# LTHPN_STD                                   -0.421209
# PTRT_MENIS_YN                               -0.397223
# GM_RENAL_DIS_YN                             -0.337361
# GM_HEENT_YN                                 -0.308679
# RESECTION_GAPBALANCE                        -0.285575
# GM_HEMA_DIS_YN                              -0.282163
# GM_OTHER_YN                                 -0.264714
# PTRT_ORIF_YN                                -0.243518
# preop PKIP confidence                       -0.237216
# PTRT_SYNOV_YN                               -0.222860
# ST_POST_LAT_CAP_YN                          -0.219133
# GM_HYPCHOL_YN                               -0.216710
# INSTRUMENTS_RUI                             -0.210808
# BMI                                         -0.198753
# AP Alignment Angle                          -0.189437
# preop KS_PAT_SAT1                           -0.184773
# ...                                               ...
# GM_DEPRESS_YN                                0.311330
# PTRT_LIG_RECON_YN                            0.315387
# ANAT_DEGREE_normalized VAR-VAL_-25_+25       0.316976
# SRG_APPROACH_TRIVECTOR                       0.355908
# ST_LAT_RETIN_YN                              0.406000
# PAT_LAT_RELEASE_YN                           0.426908
# ST_IT_BAND_YN                                0.440718
# GM_STENOSIS_YN                               0.444580
# PRIDX1_OA                                    0.461895
# COM_ASSIST_YN                                0.464882
# GM_H_SMOKER_YN                               0.474123
# ST_NONE_YN                                   0.480572
# ST_DEEP_MCL_YN                               0.497710
# PAT_MANAGE_EVERTED                           0.533420
# DEVIMP_PSFB                                  0.550356
# PTRT_CODBR_YN                                0.573528
# ST_PES_ANSER_YN                              0.606345
# preop KS_PAT_SAT4                            0.668978
# ANTI_CEMENT                                  0.691454
# GM_BACK_PAIN_YN                              0.703608
# PTRT_ODBR_YN                                 0.750859
# preop KS_PAIN_STAIRS                         0.862542
# ST_ILL_TRACT_YN                              0.871976
# AGE (normalized 30-80)                       0.882115
# INCISION_LATERAL                             0.887736
# preop KS_PAT_EXP2                            0.933451
# DEVIMP_PSRP                                  0.942017
# preop PKIP satisfaction                      0.973114
# PROC_DUR_MIN (normalized 25 to 230 min)      1.380738
# PRIDX3_PTA                                   1.523475
#
# [123 rows x 1 columns]

# %%
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((lm.predict(X) - y) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % lm.score(X, y))
# Out:
# Mean squared error: 1.99
# Variance score: 0.41
